# %% [markdown]
# # Data enrichment
#
# [Census data available at wikipedia](https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population)
#
# Workflow:
# 1. Delete the disputed boundaries.
# 2. Read the census file
# 3. Add new fields in the attribute table
# 4. Update the table
# 5. Add metadata

# %%
import arcpy

# Environment settings
arcpy.env.workspace = r"C:\Users\nomitrawat\Documents\Training\Data\Administrative Boundary Database"
arcpy.overwriteOutput = True

# Copy the feature class
result = arcpy.management.Copy("STATE_BOUNDARY_COPY.shp", "STATE.shp")

# Delete the disputed geometries
fields = ["STATE"]

with arcpy.da.UpdateCursor(result, fields) as cursor:
    for row in cursor:
        state_name = row[0]
        
        if state_name[:8] == "DISPUTED":
            cursor.deleteRow()

# %% [markdown]
# # Census Data
#
# Source: Wikipedia
# Create a dictionary so that adding data to attribute table is easy

# %%
census = r"C:\Users\nomitrawat\Documents\Training\Data\India population census.tsv"
f = open(census, "r")
lines = f.readlines()

state_details = {}

#Skip the header
for line in lines[1:]:
    details = line.split("\t")
    state_details[details[0]]=[details[1].strip().replace(",", ""), details[2].strip().replace(",", ""), details[3].strip().replace(",", ""), details[4].strip().replace(",", "").replace("\n", "")]


for key, value in state_details.items():
    print(f"Name of the state :{key}")
    print(f"Population in 2011 :{value[0]}")
    print(f"Population in 2023 :{value[1]}")
    print(f"Urban population 2011 :{value[2]}")
    print(f"Rural population 2011 :{value[3]}")
    # print(f"Total population in 2011 matches sum of rural and urban :{int(value[2])+int(value[3])==int(value[0])}")
    print("\n")

print(f"Total number of the items in state_details : {len(state_details)}")
# Out:
# Name of the state :ANDAMAN & NICOBAR
# Population in 2011 :380581
# Population in 2023 :403000
# Urban population 2011 :237093
# Rural population 2011 :143488
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :ANDHRA PRADESH
# Population in 2011 :49577103
# Population in 2023 :53156000
# Urban population 2011 :34966693
# Rural population 2011 :14610410
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :ARUNACHAL PRADESH
# Population in 2011 :1383727
# Population in 2023 :1562000
# Urban population 2011 :1066358
# Rural population 2011 :317369
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :ASSAM
# Population in 2011 :31205576
# Population in 2023 :35713000
# Urban population 2011 :26807034
# Rural population 2011 :4398542
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :BIHAR
# Population in 2011 :104099452
# Population in 2023 :126756000
# Urban population 2011 :92341436
# Rural population 2011 :11758016
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :CHANDIGARH
# Population in 2011 :1055450
# Population in 2023 :1231000
# Urban population 2011 :28991
# Rural population 2011 :1026459
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :CHHATTISGARH
# Population in 2011 :25545198
# Population in 2023 :30180000
# Urban population 2011 :19607961
# Rural population 2011 :5937237
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :DADRA & NAGAR HAVELI & DAMAN & DIU
# Population in 2011 :585764
# Population in 2023 :1263000
# Urban population 2011 :243510
# Rural population 2011 :342254
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :GOA
# Population in 2011 :1458545
# Population in 2023 :1575000
# Urban population 2011 :551731
# Rural population 2011 :906814
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :GUJARAT
# Population in 2011 :60439692
# Population in 2023 :71507000
# Urban population 2011 :34694609
# Rural population 2011 :25745083
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :HARYANA
# Population in 2011 :25351462
# Population in 2023 :30209000
# Urban population 2011 :16509359
# Rural population 2011 :8842103
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :HIMACHAL PRADESH
# Population in 2011 :6864602
# Population in 2023 :7468000
# Urban population 2011 :6176050
# Rural population 2011 :688552
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :JAMMU AND KASHMIR
# Population in 2011 :12267032
# Population in 2023 :13603000
# Urban population 2011 :9064220
# Rural population 2011 :3202812
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :JHARKHAND
# Population in 2011 :32988134
# Population in 2023 :39466000
# Urban population 2011 :25055073
# Rural population 2011 :7933061
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :KARNATAKA
# Population in 2011 :61095297
# Population in 2023 :67692000
# Urban population 2011 :37469335
# Rural population 2011 :23625962
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :KERALA
# Population in 2011 :33406061
# Population in 2023 :35776000
# Urban population 2011 :17471135
# Rural population 2011 :15934926
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :LADAKH
# Population in 2011 :274000
# Population in 2023 :300000
# Urban population 2011 :43840
# Rural population 2011 :230160
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :LAKSHADWEEP
# Population in 2011 :64473
# Population in 2023 :69000
# Urban population 2011 :14141
# Rural population 2011 :50332
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :MADHYA PRADESH
# Population in 2011 :72626809
# Population in 2023 :86579000
# Urban population 2011 :52557404
# Rural population 2011 :20069405
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :MAHARASHTRA
# Population in 2011 :112374333
# Population in 2023 :126385000
# Urban population 2011 :61556074
# Rural population 2011 :50818259
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :MANIPUR
# Population in 2011 :2570390
# Population in 2023 :3223000
# Urban population 2011 :1793875
# Rural population 2011 :776515
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :MEGHALAYA
# Population in 2011 :2966889
# Population in 2023 :3349000
# Urban population 2011 :2371439
# Rural population 2011 :595450
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :MIZORAM
# Population in 2011 :1097206
# Population in 2023 :1238000
# Urban population 2011 :525435
# Rural population 2011 :571771
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :NAGALAND
# Population in 2011 :1978502
# Population in 2023 :2233000
# Urban population 2011 :1407536
# Rural population 2011 :570966
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :DELHI
# Population in 2011 :16787941
# Population in 2023 :21359000
# Urban population 2011 :419042
# Rural population 2011 :16368899
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :ODISHA
# Population in 2011 :41974219
# Population in 2023 :46276000
# Urban population 2011 :34970562
# Rural population 2011 :7003656
# Is urban + rural =? pop in 11: False
#
#
# Name of the state :PUDUCHERRY
# Population in 2011 :1247953
# Population in 2023 :1646000
# Urban population 2011 :395200
# Rural population 2011 :852753
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :PUNJAB
# Population in 2011 :27743338
# Population in 2023 :30730000
# Urban population 2011 :17344192
# Rural population 2011 :10399146
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :RAJASTHAN
# Population in 2011 :68548437
# Population in 2023 :81025000
# Urban population 2011 :51500352
# Rural population 2011 :17048085
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :SIKKIM
# Population in 2011 :610577
# Population in 2023 :689000
# Urban population 2011 :456999
# Rural population 2011 :153578
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :TAMIL NADU
# Population in 2011 :72147030
# Population in 2023 :76860000
# Urban population 2011 :37229590
# Rural population 2011 :34917440
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :TELANGANA
# Population in 2011 :35003674
# Population in 2023 :38090000
# Urban population 2011 :21395009
# Rural population 2011 :13608665
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :TRIPURA
# Population in 2011 :3673917
# Population in 2023 :4147000
# Urban population 2011 :2712464
# Rural population 2011 :961453
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :UTTAR PRADESH
# Population in 2011 :199812341
# Population in 2023 :235687000
# Urban population 2011 :155317278
# Rural population 2011 :44495063
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :UTTARAKHAND
# Population in 2011 :10086292
# Population in 2023 :11637000
# Urban population 2011 :7036954
# Rural population 2011 :3049338
# Is urban + rural =? pop in 11: True
#
#
# Name of the state :WEST BENGAL
# Population in 2011 :91276115
# Population in 2023 :99084000
# Urban population 2011 :62183113
# Rural population 2011 :29093002
# Is urban + rural =? pop in 11: True
#
#
# Total number of the items in state_details : 36

# %% [markdown]
# Adding new fields in the "STATE.shp" to load all the data. Possible to multiple new fields by creating a list of lists.

# %%
arcpy.management.AddFields(result,
                           [['pop11', 'LONG'],
                            ['pop23', 'LONG'],
                            ['urbn_pop11', 'LONG'],
                            ['rurl_pop11', 'LONG']])
# Out:
# <Result 'C:\\Users\\nomitrawat\\Documents\\Training\\Data\\Administrative Boundary Database\\STATE.shp'>

# %% [markdown]
# Update the newly added fields

# %%
fields = ["STATE", "pop11", "pop23", "urbn_pop11", "rurl_pop11"]
with arcpy.da.UpdateCursor(result, fields) as cursor:
    for row in cursor:
        row[1] = state_details[row[0]][0]
        row[2] = state_details[row[0]][1]
        row[3] = state_details[row[0]][2]
        row[4] = state_details[row[0]][3]
    
        cursor.updateRow(row)

# %% [markdown]
# # Metadata
#
# Updating the metadata involves
# 1. Getting the metadata
# 2. Updating it
# 3. Save the changes

# %%
metadata = arcpy.metadata.Metadata(result)

metadata.title = "India state with population census"
metadata.tags = "India, States, Population"
metadata.summary = "The data contains boundaries of the state along with population census"
metadata.description = "The population census is for the years 2011 and 2023"
metadata.credits = "Survey of India, Wikipedia"

metadata.save()

# %% [markdown]
# # Exercise
# 1. Check for all the states whether the count the sum of urban and the rural population in 2011 is equal to the total population in 2011.
# 2. If you find any state showing discrepency from first exercise, add note regarding the same in the metadata description.
